# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
import keras 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers.legacy import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold

# %%
train_data_dir = '/content/drive/MyDrive/Datos6/Rosas/Rosas/Train'  
test_data_dir = '/content/drive/MyDrive/Datos6/Rosas/Rosas/Test'
validation_data_dir = '/content/drive/MyDrive/Datos6/Rosas/Rosas/Validation'

class_name = ['Sanas', 'Enfermas']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Reescalamos las imágenes
    rotation_range=10,  # Rotación aleatoria
    zoom_range=0.2,  # Zoom aleatorio
    width_shift_range=0.2,  # Traslación horizontal aleatoria
    height_shift_range=0.2,  # Traslación vertical aleatoria
    horizontal_flip=True,
    vertical_flip=True,  # Volteo horizontal aleatorio
    preprocessing_function=preprocess_input, 
    fill_mode='nearest',
    data_format="channels_last")


test_datagen = ImageDataGenerator(
    rescale=1./255,  # Reescalamos las imágenes
    rotation_range=10,  # Rotación aleatoria
    zoom_range=0.2,  # Zoom aleatorio
    width_shift_range=0.2,  # Traslación horizontal aleatoria
    height_shift_range=0.2,  # Traslación vertical aleatoria
    horizontal_flip=True,
    vertical_flip=True,  # Volteo horizontal aleatorio
    preprocessing_function=preprocess_input, 
    fill_mode='nearest',
    data_format="channels_last")

valid_datagen = ImageDataGenerator(
    rescale=1./255,  # Reescalamos las imágenes
    rotation_range=10,  # Rotación aleatoria
    zoom_range=0.2,  # Zoom aleatorio
    width_shift_range=0.2,  # Traslación horizontal aleatoria
    height_shift_range=0.2,  # Traslación vertical aleatoria
    horizontal_flip=True,
    vertical_flip=True,  # Volteo horizontal aleatorio
    preprocessing_function=preprocess_input, 
    fill_mode='nearest',
    data_format="channels_last")

# %%
train_generator = train_datagen.flow_from_directory(  
    train_data_dir,
    target_size=(255, 255),
    batch_size=32,
    #subset='training'
    #class_mode='binary'
    )

test_generator = test_datagen.flow_from_directory(  
    test_data_dir,
    target_size=(255, 255),
    batch_size=32
    #class_mode='binary'
    )

validation_generator = valid_datagen.flow_from_directory(  
    validation_data_dir,
    target_size=(255, 255),
    batch_size=32
    #class_mode='binary'
    )
# Out:
# Found 1741 images belonging to 2 classes.
# Found 216 images belonging to 2 classes.
# Found 216 images belonging to 2 classes.

# %%
from keras.layers import Dense, Flatten 
from keras.models import Model

# %%
base_model = VGG19(input_shape= (255, 255, 3), weights='imagenet', include_top= False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 4s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
X = Flatten()(base_model.output)
X = Dense(units=64, activation='relu')(X)
prediction= Dense(2, activation= 'sigmoid')(X)
model = Model(base_model.input, outputs= prediction)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 255, 255, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 255, 255, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 127, 127, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 127, 127, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 127, 127, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 63, 63, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 63, 63, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 63, 63, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 31, 31, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 31, 31, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 64)                1605696
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 21,630,210
# Trainable params: 1,605,826
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
es = EarlyStopping(monitor = 'val_loss', patience = 30, verbose= 1)

mc = ModelCheckpoint(monitor = 'val_loss', 
                     #min_delta = 0.01, 
                     patience = 30, 
                     verbose=1, 
                     save_best_only= True)

cb= [es, mc]

# %%
model.compile(optimizer='adam', 
              loss=keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
his = model.fit(train_generator,
                          epochs= 100,
                          verbose= 1, 
                          callbacks=cb,
                          validation_data= test_generator)
                          #steps_per_epoch=int(1016/32),
                          #validation_steps=int(128/32))
# Out:
# Epoch 1/100
# 55/55 [==============================] - ETA: 0s - loss: 0.7997 - accuracy: 0.6473
# Epoch 1: val_loss improved from inf to 0.63124, saving model to model6VGG19.h5
# 55/55 [==============================] - 1024s 19s/step - loss: 0.7997 - accuracy: 0.6473 - val_loss: 0.6312 - val_accuracy: 0.6574
# Epoch 2/100
# 55/55 [==============================] - ETA: 0s - loss: 0.5134 - accuracy: 0.7766
# Epoch 2: val_loss improved from 0.63124 to 0.55647, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.5134 - accuracy: 0.7766 - val_loss: 0.5565 - val_accuracy: 0.7222
# Epoch 3/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4475 - accuracy: 0.8128
# Epoch 3: val_loss improved from 0.55647 to 0.52837, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.4475 - accuracy: 0.8128 - val_loss: 0.5284 - val_accuracy: 0.7593
# Epoch 4/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8311
# Epoch 4: val_loss did not improve from 0.52837
# 55/55 [==============================] - 199s 4s/step - loss: 0.4084 - accuracy: 0.8311 - val_loss: 0.6164 - val_accuracy: 0.7130
# Epoch 5/100
# 55/55 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.8110
# Epoch 5: val_loss did not improve from 0.52837
# 55/55 [==============================] - 200s 4s/step - loss: 0.4322 - accuracy: 0.8110 - val_loss: 0.5306 - val_accuracy: 0.7407
# Epoch 6/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8472
# Epoch 6: val_loss did not improve from 0.52837
# 55/55 [==============================] - 199s 4s/step - loss: 0.3722 - accuracy: 0.8472 - val_loss: 0.5620 - val_accuracy: 0.7269
# Epoch 7/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8530
# Epoch 7: val_loss did not improve from 0.52837
# 55/55 [==============================] - 201s 4s/step - loss: 0.3497 - accuracy: 0.8530 - val_loss: 0.6085 - val_accuracy: 0.7083
# Epoch 8/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8547
# Epoch 8: val_loss did not improve from 0.52837
# 55/55 [==============================] - 199s 4s/step - loss: 0.3573 - accuracy: 0.8547 - val_loss: 0.6509 - val_accuracy: 0.6991
# Epoch 9/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3524 - accuracy: 0.8317
# Epoch 9: val_loss improved from 0.52837 to 0.52089, saving model to model6VGG19.h5
# 55/55 [==============================] - 197s 4s/step - loss: 0.3524 - accuracy: 0.8317 - val_loss: 0.5209 - val_accuracy: 0.7685
# Epoch 10/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3401 - accuracy: 0.8621
# Epoch 10: val_loss did not improve from 0.52089
# 55/55 [==============================] - 196s 4s/step - loss: 0.3401 - accuracy: 0.8621 - val_loss: 0.5247 - val_accuracy: 0.7546
# Epoch 11/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8656
# Epoch 11: val_loss did not improve from 0.52089
# 55/55 [==============================] - 197s 4s/step - loss: 0.3111 - accuracy: 0.8656 - val_loss: 0.5786 - val_accuracy: 0.7361
# Epoch 12/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.8576
# Epoch 12: val_loss did not improve from 0.52089
# 55/55 [==============================] - 194s 4s/step - loss: 0.3250 - accuracy: 0.8576 - val_loss: 0.5351 - val_accuracy: 0.7500
# Epoch 13/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.8851
# Epoch 13: val_loss improved from 0.52089 to 0.48462, saving model to model6VGG19.h5
# 55/55 [==============================] - 196s 4s/step - loss: 0.2926 - accuracy: 0.8851 - val_loss: 0.4846 - val_accuracy: 0.7454
# Epoch 14/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.8662
# Epoch 14: val_loss did not improve from 0.48462
# 55/55 [==============================] - 198s 4s/step - loss: 0.3108 - accuracy: 0.8662 - val_loss: 0.6295 - val_accuracy: 0.7407
# Epoch 15/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3072 - accuracy: 0.8771
# Epoch 15: val_loss did not improve from 0.48462
# 55/55 [==============================] - 200s 4s/step - loss: 0.3072 - accuracy: 0.8771 - val_loss: 0.5124 - val_accuracy: 0.7639
# Epoch 16/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.8587
# Epoch 16: val_loss did not improve from 0.48462
# 55/55 [==============================] - 200s 4s/step - loss: 0.3238 - accuracy: 0.8587 - val_loss: 0.5986 - val_accuracy: 0.7546
# Epoch 17/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8736
# Epoch 17: val_loss did not improve from 0.48462
# 55/55 [==============================] - 198s 4s/step - loss: 0.2866 - accuracy: 0.8736 - val_loss: 0.5300 - val_accuracy: 0.7685
# Epoch 18/100
# 55/55 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8679
# Epoch 18: val_loss improved from 0.48462 to 0.46296, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.3061 - accuracy: 0.8679 - val_loss: 0.4630 - val_accuracy: 0.7917
# Epoch 19/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.8903
# Epoch 19: val_loss did not improve from 0.46296
# 55/55 [==============================] - 196s 4s/step - loss: 0.2724 - accuracy: 0.8903 - val_loss: 0.5208 - val_accuracy: 0.7500
# Epoch 20/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.8943
# Epoch 20: val_loss did not improve from 0.46296
# 55/55 [==============================] - 197s 4s/step - loss: 0.2656 - accuracy: 0.8943 - val_loss: 0.5905 - val_accuracy: 0.7130
# Epoch 21/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8880
# Epoch 21: val_loss did not improve from 0.46296
# 55/55 [==============================] - 197s 4s/step - loss: 0.2648 - accuracy: 0.8880 - val_loss: 0.6012 - val_accuracy: 0.7546
# Epoch 22/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8794
# Epoch 22: val_loss did not improve from 0.46296
# 55/55 [==============================] - 196s 4s/step - loss: 0.2861 - accuracy: 0.8794 - val_loss: 0.5685 - val_accuracy: 0.7222
# Epoch 23/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.8914
# Epoch 23: val_loss did not improve from 0.46296
# 55/55 [==============================] - 197s 4s/step - loss: 0.2662 - accuracy: 0.8914 - val_loss: 0.4878 - val_accuracy: 0.8194
# Epoch 24/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8868
# Epoch 24: val_loss did not improve from 0.46296
# 55/55 [==============================] - 196s 4s/step - loss: 0.2637 - accuracy: 0.8868 - val_loss: 0.5339 - val_accuracy: 0.7778
# Epoch 25/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.8702
# Epoch 25: val_loss did not improve from 0.46296
# 55/55 [==============================] - 197s 4s/step - loss: 0.2990 - accuracy: 0.8702 - val_loss: 0.4977 - val_accuracy: 0.7963
# Epoch 26/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2908 - accuracy: 0.8765
# Epoch 26: val_loss did not improve from 0.46296
# 55/55 [==============================] - 196s 4s/step - loss: 0.2908 - accuracy: 0.8765 - val_loss: 0.4823 - val_accuracy: 0.7870
# Epoch 27/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2781 - accuracy: 0.8800
# Epoch 27: val_loss did not improve from 0.46296
# 55/55 [==============================] - 195s 4s/step - loss: 0.2781 - accuracy: 0.8800 - val_loss: 0.4807 - val_accuracy: 0.8148
# Epoch 28/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.8817
# Epoch 28: val_loss did not improve from 0.46296
# 55/55 [==============================] - 197s 4s/step - loss: 0.2744 - accuracy: 0.8817 - val_loss: 0.5061 - val_accuracy: 0.7870
# Epoch 29/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8914
# Epoch 29: val_loss did not improve from 0.46296
# 55/55 [==============================] - 196s 4s/step - loss: 0.2663 - accuracy: 0.8914 - val_loss: 0.4830 - val_accuracy: 0.8102
# Epoch 30/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8920
# Epoch 30: val_loss improved from 0.46296 to 0.43737, saving model to model6VGG19.h5
# 55/55 [==============================] - 196s 4s/step - loss: 0.2657 - accuracy: 0.8920 - val_loss: 0.4374 - val_accuracy: 0.8056
# Epoch 31/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9052
# Epoch 31: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2388 - accuracy: 0.9052 - val_loss: 0.5409 - val_accuracy: 0.7685
# Epoch 32/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2555 - accuracy: 0.8926
# Epoch 32: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2555 - accuracy: 0.8926 - val_loss: 0.5027 - val_accuracy: 0.7917
# Epoch 33/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.8805
# Epoch 33: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2880 - accuracy: 0.8805 - val_loss: 0.5816 - val_accuracy: 0.7546
# Epoch 34/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2499 - accuracy: 0.9001
# Epoch 34: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2499 - accuracy: 0.9001 - val_loss: 0.5489 - val_accuracy: 0.7685
# Epoch 35/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9006
# Epoch 35: val_loss did not improve from 0.43737
# 55/55 [==============================] - 197s 4s/step - loss: 0.2411 - accuracy: 0.9006 - val_loss: 0.6021 - val_accuracy: 0.7500
# Epoch 36/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9047
# Epoch 36: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2352 - accuracy: 0.9047 - val_loss: 0.5312 - val_accuracy: 0.8009
# Epoch 37/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2817 - accuracy: 0.8811
# Epoch 37: val_loss did not improve from 0.43737
# 55/55 [==============================] - 197s 4s/step - loss: 0.2817 - accuracy: 0.8811 - val_loss: 0.4412 - val_accuracy: 0.7963
# Epoch 38/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.8926
# Epoch 38: val_loss did not improve from 0.43737
# 55/55 [==============================] - 197s 4s/step - loss: 0.2540 - accuracy: 0.8926 - val_loss: 0.5725 - val_accuracy: 0.7685
# Epoch 39/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2534 - accuracy: 0.8955
# Epoch 39: val_loss did not improve from 0.43737
# 55/55 [==============================] - 195s 4s/step - loss: 0.2534 - accuracy: 0.8955 - val_loss: 0.4908 - val_accuracy: 0.8102
# Epoch 40/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.8949
# Epoch 40: val_loss did not improve from 0.43737
# 55/55 [==============================] - 196s 4s/step - loss: 0.2575 - accuracy: 0.8949 - val_loss: 0.5084 - val_accuracy: 0.8009
# Epoch 41/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.8932
# Epoch 41: val_loss did not improve from 0.43737
# 55/55 [==============================] - 195s 4s/step - loss: 0.2483 - accuracy: 0.8932 - val_loss: 0.5810 - val_accuracy: 0.7963
# Epoch 42/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9138
# Epoch 42: val_loss did not improve from 0.43737
# 55/55 [==============================] - 195s 4s/step - loss: 0.2138 - accuracy: 0.9138 - val_loss: 0.5036 - val_accuracy: 0.7870
# Epoch 43/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.8960
# Epoch 43: val_loss did not improve from 0.43737
# 55/55 [==============================] - 195s 4s/step - loss: 0.2418 - accuracy: 0.8960 - val_loss: 0.4812 - val_accuracy: 0.8009
# Epoch 44/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9138
# Epoch 44: val_loss did not improve from 0.43737
# 55/55 [==============================] - 195s 4s/step - loss: 0.2292 - accuracy: 0.9138 - val_loss: 0.5618 - val_accuracy: 0.8056
# Epoch 45/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8949
# Epoch 45: val_loss did not improve from 0.43737
# 55/55 [==============================] - 194s 4s/step - loss: 0.2580 - accuracy: 0.8949 - val_loss: 0.5821 - val_accuracy: 0.7824
# Epoch 46/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2422 - accuracy: 0.9006
# Epoch 46: val_loss did not improve from 0.43737
# 55/55 [==============================] - 197s 4s/step - loss: 0.2422 - accuracy: 0.9006 - val_loss: 0.4421 - val_accuracy: 0.8194
# Epoch 47/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9098
# Epoch 47: val_loss did not improve from 0.43737
# 55/55 [==============================] - 199s 4s/step - loss: 0.2356 - accuracy: 0.9098 - val_loss: 0.5602 - val_accuracy: 0.7361
# Epoch 48/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9115
# Epoch 48: val_loss did not improve from 0.43737
# 55/55 [==============================] - 199s 4s/step - loss: 0.2328 - accuracy: 0.9115 - val_loss: 0.4982 - val_accuracy: 0.8194
# Epoch 49/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9058
# Epoch 49: val_loss improved from 0.43737 to 0.43607, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.2372 - accuracy: 0.9058 - val_loss: 0.4361 - val_accuracy: 0.8287
# Epoch 50/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9052
# Epoch 50: val_loss did not improve from 0.43607
# 55/55 [==============================] - 198s 4s/step - loss: 0.2416 - accuracy: 0.9052 - val_loss: 0.4956 - val_accuracy: 0.7731
# Epoch 51/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.9052
# Epoch 51: val_loss did not improve from 0.43607
# 55/55 [==============================] - 197s 4s/step - loss: 0.2425 - accuracy: 0.9052 - val_loss: 0.5510 - val_accuracy: 0.8009
# Epoch 52/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2336 - accuracy: 0.9070
# Epoch 52: val_loss improved from 0.43607 to 0.41814, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.2336 - accuracy: 0.9070 - val_loss: 0.4181 - val_accuracy: 0.8333
# Epoch 53/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.8914
# Epoch 53: val_loss did not improve from 0.41814
# 55/55 [==============================] - 197s 4s/step - loss: 0.2513 - accuracy: 0.8914 - val_loss: 0.7074 - val_accuracy: 0.7454
# Epoch 54/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9058
# Epoch 54: val_loss did not improve from 0.41814
# 55/55 [==============================] - 196s 4s/step - loss: 0.2317 - accuracy: 0.9058 - val_loss: 0.4420 - val_accuracy: 0.8148
# Epoch 55/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9138
# Epoch 55: val_loss did not improve from 0.41814
# 55/55 [==============================] - 196s 4s/step - loss: 0.2293 - accuracy: 0.9138 - val_loss: 0.4847 - val_accuracy: 0.7917
# Epoch 56/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2401 - accuracy: 0.8943
# Epoch 56: val_loss did not improve from 0.41814
# 55/55 [==============================] - 197s 4s/step - loss: 0.2401 - accuracy: 0.8943 - val_loss: 0.4347 - val_accuracy: 0.8287
# Epoch 57/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.8845
# Epoch 57: val_loss did not improve from 0.41814
# 55/55 [==============================] - 198s 4s/step - loss: 0.2731 - accuracy: 0.8845 - val_loss: 0.5625 - val_accuracy: 0.7639
# Epoch 58/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9087
# Epoch 58: val_loss did not improve from 0.41814
# 55/55 [==============================] - 198s 4s/step - loss: 0.2283 - accuracy: 0.9087 - val_loss: 0.4422 - val_accuracy: 0.8333
# Epoch 59/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.8937
# Epoch 59: val_loss did not improve from 0.41814
# 55/55 [==============================] - 198s 4s/step - loss: 0.2533 - accuracy: 0.8937 - val_loss: 0.4520 - val_accuracy: 0.8194
# Epoch 60/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9029
# Epoch 60: val_loss improved from 0.41814 to 0.38699, saving model to model6VGG19.h5
# 55/55 [==============================] - 198s 4s/step - loss: 0.2338 - accuracy: 0.9029 - val_loss: 0.3870 - val_accuracy: 0.8519
# Epoch 61/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9092
# Epoch 61: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2115 - accuracy: 0.9092 - val_loss: 0.5073 - val_accuracy: 0.8056
# Epoch 62/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9098
# Epoch 62: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.2251 - accuracy: 0.9098 - val_loss: 0.5318 - val_accuracy: 0.7963
# Epoch 63/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9138
# Epoch 63: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.2238 - accuracy: 0.9138 - val_loss: 0.4319 - val_accuracy: 0.8148
# Epoch 64/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9006
# Epoch 64: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2360 - accuracy: 0.9006 - val_loss: 0.5520 - val_accuracy: 0.7685
# Epoch 65/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9058
# Epoch 65: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2261 - accuracy: 0.9058 - val_loss: 0.4870 - val_accuracy: 0.7824
# Epoch 66/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2233 - accuracy: 0.9012
# Epoch 66: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2233 - accuracy: 0.9012 - val_loss: 0.4984 - val_accuracy: 0.8102
# Epoch 67/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.8851
# Epoch 67: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2626 - accuracy: 0.8851 - val_loss: 0.6428 - val_accuracy: 0.7778
# Epoch 68/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9052
# Epoch 68: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2392 - accuracy: 0.9052 - val_loss: 0.5338 - val_accuracy: 0.7685
# Epoch 69/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2193 - accuracy: 0.9144
# Epoch 69: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2193 - accuracy: 0.9144 - val_loss: 0.5644 - val_accuracy: 0.7870
# Epoch 70/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2040 - accuracy: 0.9202
# Epoch 70: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2040 - accuracy: 0.9202 - val_loss: 0.5450 - val_accuracy: 0.8194
# Epoch 71/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9184
# Epoch 71: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.1981 - accuracy: 0.9184 - val_loss: 0.6289 - val_accuracy: 0.7639
# Epoch 72/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9081
# Epoch 72: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2169 - accuracy: 0.9081 - val_loss: 0.4186 - val_accuracy: 0.8426
# Epoch 73/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9138
# Epoch 73: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2157 - accuracy: 0.9138 - val_loss: 0.6162 - val_accuracy: 0.7546
# Epoch 74/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9207
# Epoch 74: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.1981 - accuracy: 0.9207 - val_loss: 0.4874 - val_accuracy: 0.8102
# Epoch 75/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9196
# Epoch 75: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2054 - accuracy: 0.9196 - val_loss: 0.5136 - val_accuracy: 0.7870
# Epoch 76/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9248
# Epoch 76: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.1965 - accuracy: 0.9248 - val_loss: 0.5192 - val_accuracy: 0.7731
# Epoch 77/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9041
# Epoch 77: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2430 - accuracy: 0.9041 - val_loss: 0.6506 - val_accuracy: 0.7500
# Epoch 78/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2407 - accuracy: 0.9047
# Epoch 78: val_loss did not improve from 0.38699
# 55/55 [==============================] - 198s 4s/step - loss: 0.2407 - accuracy: 0.9047 - val_loss: 0.6098 - val_accuracy: 0.7917
# Epoch 79/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8989
# Epoch 79: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.2390 - accuracy: 0.8989 - val_loss: 0.4134 - val_accuracy: 0.8009
# Epoch 80/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.8989
# Epoch 80: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.2449 - accuracy: 0.8989 - val_loss: 0.4527 - val_accuracy: 0.8194
# Epoch 81/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9225
# Epoch 81: val_loss did not improve from 0.38699
# 55/55 [==============================] - 197s 4s/step - loss: 0.2012 - accuracy: 0.9225 - val_loss: 0.5113 - val_accuracy: 0.8194
# Epoch 82/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2232 - accuracy: 0.9104
# Epoch 82: val_loss did not improve from 0.38699
# 55/55 [==============================] - 196s 4s/step - loss: 0.2232 - accuracy: 0.9104 - val_loss: 0.4910 - val_accuracy: 0.7917
# Epoch 83/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2072 - accuracy: 0.9179
# Epoch 83: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2072 - accuracy: 0.9179 - val_loss: 0.5192 - val_accuracy: 0.8148
# Epoch 84/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9236
# Epoch 84: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.1883 - accuracy: 0.9236 - val_loss: 0.4861 - val_accuracy: 0.8102
# Epoch 85/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.8978
# Epoch 85: val_loss did not improve from 0.38699
# 55/55 [==============================] - 195s 4s/step - loss: 0.2584 - accuracy: 0.8978 - val_loss: 0.5433 - val_accuracy: 0.7685
# Epoch 86/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2510 - accuracy: 0.8920
# Epoch 86: val_loss did not improve from 0.38699
# 55/55 [==============================] - 199s 4s/step - loss: 0.2510 - accuracy: 0.8920 - val_loss: 0.4462 - val_accuracy: 0.8056
# Epoch 87/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2297 - accuracy: 0.9006
# Epoch 87: val_loss did not improve from 0.38699
# 55/55 [==============================] - 199s 4s/step - loss: 0.2297 - accuracy: 0.9006 - val_loss: 0.4875 - val_accuracy: 0.8148
# Epoch 88/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.8989
# Epoch 88: val_loss did not improve from 0.38699
# 55/55 [==============================] - 200s 4s/step - loss: 0.2248 - accuracy: 0.8989 - val_loss: 0.4726 - val_accuracy: 0.8194
# Epoch 89/100
# 55/55 [==============================] - ETA: 0s - loss: 0.2021 - accuracy: 0.9150
# Epoch 89: val_loss did not improve from 0.38699
# 55/55 [==============================] - 199s 4s/step - loss: 0.2021 - accuracy: 0.9150 - val_loss: 0.4612 - val_accuracy: 0.8056
# Epoch 90/100
# 55/55 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.9242
# Epoch 90: val_loss did not improve from 0.38699
# 55/55 [==============================] - 200s 4s/step - loss: 0.1951 - accuracy: 0.9242 - val_loss: 0.5414 - val_accuracy: 0.7593
# Epoch 90: early stopping

# %%
hit = his.history
hit.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
h=hit
plt.plot(h['loss'])
plt.plot(h['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['test', 'train'], loc='upper right')
plt.show()

# %%
# Graficar accuracy vs epochs
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
result = model.evaluate(validation_generator)
print("Result of VGG19 Model {}%".format(round(result[1]*100,2)))
# Out:
# 7/7 [==============================] - 153s 25s/step - loss: 0.4888 - accuracy: 0.7639
# Result of VGG19 Model 76.39%

# %%
from sklearn.metrics import roc_curve, auc

# Calcular la probabilidad de predicción para el conjunto de validación
p = model.predict(validation_generator)

# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(
validation_generator.classes, p[:, 1])
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')

plt.legend(loc="lower right")
plt.show()
# Out:
# 7/7 [==============================] - 26s 4s/step

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, accuracy_score, auc, roc_curve,precision_score, precision_recall_curve
from sklearn.metrics import confusion_matrix


y_true = validation_generator.classes
y_pred = np.argmax(p, axis=1)

# Calcular la matriz de confusión
cm = confusion_matrix(y_true, y_pred)
print('Matriz de confusión:')
print(cm)

print("\n")
y_pred = np.argmax(p, axis=1)
accuracy = accuracy_score(validation_generator.classes, y_pred)
precision = precision_score(validation_generator.classes, y_pred)
recall = recall_score(validation_generator.classes, y_pred)
f1 = f1_score(validation_generator.classes, y_pred)

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 Score:', f1)
# Out:
# Matriz de confusión:
# [[63 45]
#  [57 51]]
#
#
# Accuracy: 0.5277777777777778
# Precision: 0.53125
# Recall: 0.4722222222222222
# F1 Score: 0.4999999999999999

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from keras.models import load_model
model = load_model("/content/drive/MyDrive/PI/best_model.h5")

# %%
names = ['Sana','Enferma']
modelt = load_model("/content/drive/MyDrive/PI/best_model.h5")
imaget_path = "/content/drive/MyDrive/base_Rosas/IMG_1580.jpg"
img = cv2.imread(imaget_path)
imaget = cv2.resize(img, (256,256), interpolation = cv2.INTER_AREA)
xt = np.asarray(imaget)
xt=preprocess_input(xt)
xt = np.expand_dims(xt,axis=0)
preds = modelt.predict(xt)

print('preds[0]:',preds[0])   
print(names[np.argmax(preds)],preds[0][np.argmax(preds)]*100.0,'%')
plt.imshow(cv2.cvtColor(np.asarray(imaget),cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 149ms/step
# preds[0]: [0. 1. 0.]
# Enferma 100.0 %
